# %% [markdown]
# Pandas Series - 1D array-like structure that can hold data of any type-int, str,floats.
# Pandas DataFrame - 2D, table-like structure that consists of rows and columns.

# %%
import pandas as pd

# %%
#PANDAS SERIES
#load the dataset
df = pd.read_csv('Data/Students_Grading_Dataset.csv')
df
#create pandas series from student ID Column
# student_ids = df['Student_ID']
# student_ids
# student_ages = df['Age']
# student_ages

# #checking first 5 rows from a specific column
# df['Age'].head()

# #checking last 5 rows from a specific column
# df['Age'].tail()
# Out:
#      Student_ID First_Name Last_Name                       Email  Gender  Age  \
# 0         S1000       Omar  Williams     student0@university.com  Female   22
# 1         S1001      Maria     Brown     student1@university.com    Male   18
# 2         S1002      Ahmed     Jones     student2@university.com    Male   24
# 3         S1003       Omar  Williams     student3@university.com  Female   24
# 4         S1004       John     Smith     student4@university.com  Female   23
# ...         ...        ...       ...                         ...     ...  ...
# 4995      S5995      Ahmed     Jones  student4995@university.com    Male   19
# 4996      S5996       Emma     Brown  student4996@university.com    Male   19
# 4997      S5997       John     Brown  student4997@university.com  Female   24
# 4998      S5998       Sara     Davis  student4998@university.com    Male   23
# 4999      S5999      Maria     Brown  student4999@university.com  Female   21
#
#        Department  Attendance (%)  Midterm_Score  Final_Score  ...  \
# 0     Engineering           52.29          55.03        57.82  ...
# 1     Engineering           97.27          97.23        45.80  ...
# 2        Business           57.19          67.05        93.68  ...
# 3     Mathematics           95.15          47.79        80.63  ...
# 4              CS           54.18          46.59        78.89  ...
# ...           ...             ...            ...          ...  ...
# 4995     Business             NaN          82.15        60.33  ...
# 4996     Business           65.11          86.31        49.80  ...
# 4997           CS           87.54          63.55        64.21  ...
# 4998           CS           92.56          79.79        94.28  ...
# 4999  Engineering           83.92          83.24        53.47  ...
#
#       Projects_Score  Total_Score  Grade  Study_Hours_per_Week  \
# 0              85.90        56.09      F                   6.2
# 1              55.65        50.64      A                  19.0
# 2              73.79        70.30      D                  20.7
# 3              92.12        61.63      A                  24.8
# 4              68.42        66.13      F                  15.4
# ...              ...          ...    ...                   ...
# 4995           58.42        85.21      D                  25.5
# 4996           60.87        95.96      C                   5.0
# 4997           82.65        54.25      A                  24.8
# 4998           94.29        55.84      A                  16.1
# 4999           69.25        77.86      F                  29.2
#
#       Extracurricular_Activities Internet_Access_at_Home  \
# 0                             No                     Yes
# 1                             No                     Yes
# 2                             No                     Yes
# 3                            Yes                     Yes
# 4                            Yes                     Yes
# ...                          ...                     ...
# 4995                          No                     Yes
# 4996                          No                     Yes
# 4997                         Yes                      No
# 4998                         Yes                     Yes
# 4999                          No                     Yes
#
#       Parent_Education_Level Family_Income_Level Stress_Level (1-10)  \
# 0                High School              Medium                   5
# 1                       None              Medium                   4
# 2                   Master's                 Low                   6
# 3                High School                High                   3
# 4                High School                High                   2
# ...                      ...                 ...                 ...
# 4995             High School                 Low                  10
# 4996                     NaN              Medium                   4
# 4997             High School              Medium                   4
# 4998              Bachelor's                 Low                   1
# 4999                     PhD                 Low                   2
#
#      Sleep_Hours_per_Night
# 0                      4.7
# 1                      9.0
# 2                      6.2
# 3                      6.7
# 4                      7.1
# ...                    ...
# 4995                   8.3
# 4996                   4.0
# 4997                   6.3
# 4998                   8.4
# 4999                   6.1
#
# [5000 rows x 23 columns]

# %%
#PANDAS DATAFRAME
df = pd.read_csv('Data/Students_Grading_Dataset.csv')

df_json = pd.read_json('Data/Students_Grading_Dataset.json')
df_json
# Out:
#      Student_ID First_Name Last_Name                       Email  Gender  Age  \
# 0         S1000       Omar  Williams     student0@university.com  Female   22
# 1         S1001      Maria     Brown     student1@university.com    Male   18
# 2         S1002      Ahmed     Jones     student2@university.com    Male   24
# 3         S1003       Omar  Williams     student3@university.com  Female   24
# 4         S1004       John     Smith     student4@university.com  Female   23
# ...         ...        ...       ...                         ...     ...  ...
# 4995      S5995      Ahmed     Jones  student4995@university.com    Male   19
# 4996      S5996       Emma     Brown  student4996@university.com    Male   19
# 4997      S5997       John     Brown  student4997@university.com  Female   24
# 4998      S5998       Sara     Davis  student4998@university.com    Male   23
# 4999      S5999      Maria     Brown  student4999@university.com  Female   21
#
#        Department  Attendance (%)  Midterm_Score  Final_Score  ...  \
# 0     Engineering           52.29          55.03        57.82  ...
# 1     Engineering           97.27          97.23        45.80  ...
# 2        Business           57.19          67.05        93.68  ...
# 3     Mathematics           95.15          47.79        80.63  ...
# 4              CS           54.18          46.59        78.89  ...
# ...           ...             ...            ...          ...  ...
# 4995     Business             NaN          82.15        60.33  ...
# 4996     Business           65.11          86.31        49.80  ...
# 4997           CS           87.54          63.55        64.21  ...
# 4998           CS           92.56          79.79        94.28  ...
# 4999  Engineering           83.92          83.24        53.47  ...
#
#       Projects_Score  Total_Score  Grade  Study_Hours_per_Week  \
# 0              85.90        56.09      F                   6.2
# 1              55.65        50.64      A                  19.0
# 2              73.79        70.30      D                  20.7
# 3              92.12        61.63      A                  24.8
# 4              68.42        66.13      F                  15.4
# ...              ...          ...    ...                   ...
# 4995           58.42        85.21      D                  25.5
# 4996           60.87        95.96      C                   5.0
# 4997           82.65        54.25      A                  24.8
# 4998           94.29        55.84      A                  16.1
# 4999           69.25        77.86      F                  29.2
#
#       Extracurricular_Activities Internet_Access_at_Home  \
# 0                             No                     Yes
# 1                             No                     Yes
# 2                             No                     Yes
# 3                            Yes                     Yes
# 4                            Yes                     Yes
# ...                          ...                     ...
# 4995                          No                     Yes
# 4996                          No                     Yes
# 4997                         Yes                      No
# 4998                         Yes                     Yes
# 4999                          No                     Yes
#
#       Parent_Education_Level Family_Income_Level Stress_Level (1-10)  \
# 0                High School              Medium                   5
# 1                       None              Medium                   4
# 2                   Master's                 Low                   6
# 3                High School                High                   3
# 4                High School                High                   2
# ...                      ...                 ...                 ...
# 4995             High School                 Low                  10
# 4996                    None              Medium                   4
# 4997             High School              Medium                   4
# 4998              Bachelor's                 Low                   1
# 4999                     PhD                 Low                   2
#
#      Sleep_Hours_per_Night
# 0                      4.7
# 1                      9.0
# 2                      6.2
# 3                      6.7
# 4                      7.1
# ...                    ...
# 4995                   8.3
# 4996                   4.0
# 4997                   6.3
# 4998                   8.4
# 4999                   6.1
#
# [5000 rows x 23 columns]

# %%
#summary stats
summary_stats = df.describe()
summary_stats
# Out:
#                Age  Attendance (%)  Midterm_Score  Final_Score  \
# count  5000.000000     4484.000000    5000.000000  5000.000000
# mean     21.048400       75.431409      70.326844    69.640788
# std       1.989786       14.372446      17.213209    17.238744
# min      18.000000       50.010000      40.000000    40.000000
# 25%      19.000000       63.265000      55.457500    54.667500
# 50%      21.000000       75.725000      70.510000    69.735000
# 75%      23.000000       87.472500      84.970000    84.500000
# max      24.000000      100.000000      99.980000    99.980000
#
#        Assignments_Avg  Quizzes_Avg  Participation_Score  Projects_Score  \
# count      4483.000000  5000.000000          5000.000000     5000.000000
# mean         74.798673    74.910728             4.980024       74.924860
# std          14.411799    14.504281             2.890136       14.423415
# min          50.000000    50.030000             0.000000       50.010000
# 25%          62.090000    62.490000             2.440000       62.320000
# 50%          74.810000    74.695000             4.955000       74.980000
# 75%          86.970000    87.630000             7.500000       87.367500
# max          99.980000    99.960000            10.000000      100.000000
#
#        Total_Score  Study_Hours_per_Week  Stress_Level (1-10)  \
# count  5000.000000           5000.000000           5000.00000
# mean     75.121804             17.658860              5.48080
# std      14.399941              7.275864              2.86155
# min      50.020000              5.000000              1.00000
# 25%      62.835000             11.400000              3.00000
# 50%      75.395000             17.500000              5.00000
# 75%      87.652500             24.100000              8.00000
# max      99.990000             30.000000             10.00000
#
#        Sleep_Hours_per_Night
# count            5000.000000
# mean                6.488140
# std                 1.452283
# min                 4.000000
# 25%                 5.200000
# 50%                 6.500000
# 75%                 7.700000
# max                 9.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 23 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Student_ID                  5000 non-null   object
#  1   First_Name                  5000 non-null   object
#  2   Last_Name                   5000 non-null   object
#  3   Email                       5000 non-null   object
#  4   Gender                      5000 non-null   object
#  5   Age                         5000 non-null   int64
#  6   Department                  5000 non-null   object
#  7   Attendance (%)              4484 non-null   float64
#  8   Midterm_Score               5000 non-null   float64
#  9   Final_Score                 5000 non-null   float64
#  10  Assignments_Avg             4483 non-null   float64
#  11  Quizzes_Avg                 5000 non-null   float64
#  12  Participation_Score         5000 non-null   float64
#  13  Projects_Score              5000 non-null   float64
#  14  Total_Score                 5000 non-null   float64
#  15  Grade                       5000 non-null   object
#  16  Study_Hours_per_Week        5000 non-null   float64
#  17  Extracurricular_Activities  5000 non-null   object
#  18  Internet_Access_at_Home     5000 non-null   object
#  19  Parent_Education_Level      4016 non-null   object
#  20  Family_Income_Level         5000 non-null   object
#  21  Stress_Level (1-10)         5000 non-null   int64
#  22  Sleep_Hours_per_Night       5000 non-null   float64
# dtypes: float64(10), int64(2), object(11)
# memory usage: 898.6+ KB

# %%
#summary stats for age column
mean_age = df['Age'].mean()
median_age = df['Age'].median()
sum_age = df['Age'].sum()
count_age = df['Age'].count()
cumsum_age = df['Age'].cumsum()

# %%
#changing the index of a dataframe
# df.set_index('Student_ID',inplace=True)
# df.reset_index(inplace=True)
# df

# %%
#changing dtypes of columns
# df['Age'] = df['Age'].astype(object)

# df.info()

# %%
#.map() and .apply() methods
#.map() - method used to apply a function to each element in a Pandas Series
#.apply() - method used to apply a function along either axis(rows or columns)

# %%
#.map() method
# df['Days_of_Week'] = df['Days_of_Week'].map({'Sunday':1,'Monday':2,})

df['Gender'] = df['Gender'].map({'Male':0,'Female':1})
df['Gender']
# Out:
# 0       1
# 1       0
# 2       0
# 3       1
# 4       1
#        ..
# 4995    0
# 4996    0
# 4997    1
# 4998    0
# 4999    1
# Name: Gender, Length: 5000, dtype: int64

# %%
df
# Out:
#      Student_ID First_Name Last_Name                       Email  Gender  Age  \
# 0         S1000       Omar  Williams     student0@university.com       1   22
# 1         S1001      Maria     Brown     student1@university.com       0   18
# 2         S1002      Ahmed     Jones     student2@university.com       0   24
# 3         S1003       Omar  Williams     student3@university.com       1   24
# 4         S1004       John     Smith     student4@university.com       1   23
# ...         ...        ...       ...                         ...     ...  ...
# 4995      S5995      Ahmed     Jones  student4995@university.com       0   19
# 4996      S5996       Emma     Brown  student4996@university.com       0   19
# 4997      S5997       John     Brown  student4997@university.com       1   24
# 4998      S5998       Sara     Davis  student4998@university.com       0   23
# 4999      S5999      Maria     Brown  student4999@university.com       1   21
#
#        Department  Attendance (%)  Midterm_Score  Final_Score  ...  \
# 0     Engineering           52.29          55.03        57.82  ...
# 1     Engineering           97.27          97.23        45.80  ...
# 2        Business           57.19          67.05        93.68  ...
# 3     Mathematics           95.15          47.79        80.63  ...
# 4              CS           54.18          46.59        78.89  ...
# ...           ...             ...            ...          ...  ...
# 4995     Business             NaN          82.15        60.33  ...
# 4996     Business           65.11          86.31        49.80  ...
# 4997           CS           87.54          63.55        64.21  ...
# 4998           CS           92.56          79.79        94.28  ...
# 4999  Engineering           83.92          83.24        53.47  ...
#
#       Projects_Score  Total_Score  Grade  Study_Hours_per_Week  \
# 0              85.90        56.09      F                   6.2
# 1              55.65        50.64      A                  19.0
# 2              73.79        70.30      D                  20.7
# 3              92.12        61.63      A                  24.8
# 4              68.42        66.13      F                  15.4
# ...              ...          ...    ...                   ...
# 4995           58.42        85.21      D                  25.5
# 4996           60.87        95.96      C                   5.0
# 4997           82.65        54.25      A                  24.8
# 4998           94.29        55.84      A                  16.1
# 4999           69.25        77.86      F                  29.2
#
#       Extracurricular_Activities Internet_Access_at_Home  \
# 0                             No                     Yes
# 1                             No                     Yes
# 2                             No                     Yes
# 3                            Yes                     Yes
# 4                            Yes                     Yes
# ...                          ...                     ...
# 4995                          No                     Yes
# 4996                          No                     Yes
# 4997                         Yes                      No
# 4998                         Yes                     Yes
# 4999                          No                     Yes
#
#       Parent_Education_Level Family_Income_Level Stress_Level (1-10)  \
# 0                High School              Medium                   5
# 1                       None              Medium                   4
# 2                   Master's                 Low                   6
# 3                High School                High                   3
# 4                High School                High                   2
# ...                      ...                 ...                 ...
# 4995             High School                 Low                  10
# 4996                     NaN              Medium                   4
# 4997             High School              Medium                   4
# 4998              Bachelor's                 Low                   1
# 4999                     PhD                 Low                   2
#
#      Sleep_Hours_per_Night
# 0                      4.7
# 1                      9.0
# 2                      6.2
# 3                      6.7
# 4                      7.1
# ...                    ...
# 4995                   8.3
# 4996                   4.0
# 4997                   6.3
# 4998                   8.4
# 4999                   6.1
#
# [5000 rows x 23 columns]

# %%
df['Gender'] = df['Gender'].map({1 : 'Male', 0 : 'Female'})
df
# Out:
#      Student_ID First_Name Last_Name                       Email  Gender  Age  \
# 0         S1000       Omar  Williams     student0@university.com    Male   22
# 1         S1001      Maria     Brown     student1@university.com  Female   18
# 2         S1002      Ahmed     Jones     student2@university.com  Female   24
# 3         S1003       Omar  Williams     student3@university.com    Male   24
# 4         S1004       John     Smith     student4@university.com    Male   23
# ...         ...        ...       ...                         ...     ...  ...
# 4995      S5995      Ahmed     Jones  student4995@university.com  Female   19
# 4996      S5996       Emma     Brown  student4996@university.com  Female   19
# 4997      S5997       John     Brown  student4997@university.com    Male   24
# 4998      S5998       Sara     Davis  student4998@university.com  Female   23
# 4999      S5999      Maria     Brown  student4999@university.com    Male   21
#
#        Department  Attendance (%)  Midterm_Score  Final_Score  ...  \
# 0     Engineering           52.29          55.03        57.82  ...
# 1     Engineering           97.27          97.23        45.80  ...
# 2        Business           57.19          67.05        93.68  ...
# 3     Mathematics           95.15          47.79        80.63  ...
# 4              CS           54.18          46.59        78.89  ...
# ...           ...             ...            ...          ...  ...
# 4995     Business             NaN          82.15        60.33  ...
# 4996     Business           65.11          86.31        49.80  ...
# 4997           CS           87.54          63.55        64.21  ...
# 4998           CS           92.56          79.79        94.28  ...
# 4999  Engineering           83.92          83.24        53.47  ...
#
#       Projects_Score  Total_Score  Grade  Study_Hours_per_Week  \
# 0              85.90        56.09      F                   6.2
# 1              55.65        50.64      A                  19.0
# 2              73.79        70.30      D                  20.7
# 3              92.12        61.63      A                  24.8
# 4              68.42        66.13      F                  15.4
# ...              ...          ...    ...                   ...
# 4995           58.42        85.21      D                  25.5
# 4996           60.87        95.96      C                   5.0
# 4997           82.65        54.25      A                  24.8
# 4998           94.29        55.84      A                  16.1
# 4999           69.25        77.86      F                  29.2
#
#       Extracurricular_Activities Internet_Access_at_Home  \
# 0                             No                     Yes
# 1                             No                     Yes
# 2                             No                     Yes
# 3                            Yes                     Yes
# 4                            Yes                     Yes
# ...                          ...                     ...
# 4995                          No                     Yes
# 4996                          No                     Yes
# 4997                         Yes                      No
# 4998                         Yes                     Yes
# 4999                          No                     Yes
#
#       Parent_Education_Level Family_Income_Level Stress_Level (1-10)  \
# 0                High School              Medium                   5
# 1                       None              Medium                   4
# 2                   Master's                 Low                   6
# 3                High School                High                   3
# 4                High School                High                   2
# ...                      ...                 ...                 ...
# 4995             High School                 Low                  10
# 4996                     NaN              Medium                   4
# 4997             High School              Medium                   4
# 4998              Bachelor's                 Low                   1
# 4999                     PhD                 Low                   2
#
#      Sleep_Hours_per_Night
# 0                      4.7
# 1                      9.0
# 2                      6.2
# 3                      6.7
# 4                      7.1
# ...                    ...
# 4995                   8.3
# 4996                   4.0
# 4997                   6.3
# 4998                   8.4
# 4999                   6.1
#
# [5000 rows x 23 columns]

# %%
engineering_dpt = df[df['Department'] == 'Engineering']
engineering_dpt

high_attendance = df[df['Attendance (%)'] >= 80]
high_attendance

# engineering_dpt = df['Department']
# engineering_dpt[engineering_dpt.isin(['Engineering'])]
# Out:
#      Student_ID First_Name Last_Name                       Email  Gender  Age  \
# 1         S1001      Maria     Brown     student1@university.com  Female   18
# 3         S1003       Omar  Williams     student3@university.com    Male   24
# 8         S1008       Omar     Smith     student8@university.com    Male   21
# 10        S1010       John     Smith    student10@university.com    Male   23
# 13        S1013       John  Williams    student13@university.com  Female   18
# ...         ...        ...       ...                         ...     ...  ...
# 4990      S5990        Ali   Johnson  student4990@university.com  Female   24
# 4993      S5993        Ali   Johnson  student4993@university.com    Male   22
# 4997      S5997       John     Brown  student4997@university.com    Male   24
# 4998      S5998       Sara     Davis  student4998@university.com  Female   23
# 4999      S5999      Maria     Brown  student4999@university.com    Male   21
#
#        Department  Attendance (%)  Midterm_Score  Final_Score  ...  \
# 1     Engineering           97.27          97.23        45.80  ...
# 3     Mathematics           95.15          47.79        80.63  ...
# 8              CS           85.97          84.42        90.87  ...
# 10             CS           85.72          83.52        97.43  ...
# 13       Business           96.61          40.64        93.14  ...
# ...           ...             ...            ...          ...  ...
# 4990           CS           80.53          87.83        43.70  ...
# 4993     Business           99.21          60.16        59.18  ...
# 4997           CS           87.54          63.55        64.21  ...
# 4998           CS           92.56          79.79        94.28  ...
# 4999  Engineering           83.92          83.24        53.47  ...
#
#       Projects_Score  Total_Score  Grade  Study_Hours_per_Week  \
# 1              55.65        50.64      A                  19.0
# 3              92.12        61.63      A                  24.8
# 8              94.01        95.62      A                   8.0
# 10             97.62        58.25      A                  13.2
# 13             81.48        77.93      A                  22.8
# ...              ...          ...    ...                   ...
# 4990           65.16        81.18      F                  15.2
# 4993           69.56        85.86      A                  16.9
# 4997           82.65        54.25      A                  24.8
# 4998           94.29        55.84      A                  16.1
# 4999           69.25        77.86      F                  29.2
#
#       Extracurricular_Activities Internet_Access_at_Home  \
# 1                             No                     Yes
# 3                            Yes                     Yes
# 8                             No                      No
# 10                            No                     Yes
# 13                            No                     Yes
# ...                          ...                     ...
# 4990                          No                     Yes
# 4993                          No                     Yes
# 4997                         Yes                      No
# 4998                         Yes                     Yes
# 4999                          No                     Yes
#
#       Parent_Education_Level Family_Income_Level Stress_Level (1-10)  \
# 1                       None              Medium                   4
# 3                High School                High                   3
# 8                 Bachelor's                 Low                   9
# 10               High School                 Low                   1
# 13                      None              Medium                  10
# ...                      ...                 ...                 ...
# 4990                     NaN                 Low                   7
# 4993                    None                 Low                   2
# 4997             High School              Medium                   4
# 4998              Bachelor's                 Low                   1
# 4999                     PhD                 Low                   2
#
#      Sleep_Hours_per_Night
# 1                      9.0
# 3                      6.7
# 8                      8.8
# 10                     4.1
# 13                     7.9
# ...                    ...
# 4990                   7.1
# 4993                   7.8
# 4997                   6.3
# 4998                   8.4
# 4999                   6.1
#
# [1853 rows x 23 columns]

# %%
#.apply()
def calculate_total(row):
    return row['Midterm_Score'] + row['Final_Score'] + row['Assignments_Avg'] + row['Quizzes_Avg'] + row['Participation_Score'] + row['Projects_Score']

df['Total Score'] = df.apply(calculate_total, axis=1)
df['Total Score']
df
# Out:
#      Student_ID First_Name Last_Name                       Email  Gender  Age  \
# 0         S1000       Omar  Williams     student0@university.com    Male   22
# 1         S1001      Maria     Brown     student1@university.com  Female   18
# 2         S1002      Ahmed     Jones     student2@university.com  Female   24
# 3         S1003       Omar  Williams     student3@university.com    Male   24
# 4         S1004       John     Smith     student4@university.com    Male   23
# ...         ...        ...       ...                         ...     ...  ...
# 4995      S5995      Ahmed     Jones  student4995@university.com  Female   19
# 4996      S5996       Emma     Brown  student4996@university.com  Female   19
# 4997      S5997       John     Brown  student4997@university.com    Male   24
# 4998      S5998       Sara     Davis  student4998@university.com  Female   23
# 4999      S5999      Maria     Brown  student4999@university.com    Male   21
#
#        Department  Attendance (%)  Midterm_Score  Final_Score  ...  \
# 0     Engineering           52.29          55.03        57.82  ...
# 1     Engineering           97.27          97.23        45.80  ...
# 2        Business           57.19          67.05        93.68  ...
# 3     Mathematics           95.15          47.79        80.63  ...
# 4              CS           54.18          46.59        78.89  ...
# ...           ...             ...            ...          ...  ...
# 4995     Business             NaN          82.15        60.33  ...
# 4996     Business           65.11          86.31        49.80  ...
# 4997           CS           87.54          63.55        64.21  ...
# 4998           CS           92.56          79.79        94.28  ...
# 4999  Engineering           83.92          83.24        53.47  ...
#
#       Total_Score  Grade  Study_Hours_per_Week  Extracurricular_Activities  \
# 0           56.09      F                   6.2                          No
# 1           50.64      A                  19.0                          No
# 2           70.30      D                  20.7                          No
# 3           61.63      A                  24.8                         Yes
# 4           66.13      F                  15.4                         Yes
# ...           ...    ...                   ...                         ...
# 4995        85.21      D                  25.5                          No
# 4996        95.96      C                   5.0                          No
# 4997        54.25      A                  24.8                         Yes
# 4998        55.84      A                  16.1                         Yes
# 4999        77.86      F                  29.2                          No
#
#       Internet_Access_at_Home Parent_Education_Level  Family_Income_Level  \
# 0                         Yes            High School               Medium
# 1                         Yes                   None               Medium
# 2                         Yes               Master's                  Low
# 3                         Yes            High School                 High
# 4                         Yes            High School                 High
# ...                       ...                    ...                  ...
# 4995                      Yes            High School                  Low
# 4996                      Yes                    NaN               Medium
# 4997                       No            High School               Medium
# 4998                      Yes             Bachelor's                  Low
# 4999                      Yes                    PhD                  Low
#
#      Stress_Level (1-10) Sleep_Hours_per_Night Total Score
# 0                      5                   4.7      361.02
# 1                      4                   9.0         NaN
# 2                      6                   6.2      392.97
# 3                      3                   6.7      386.65
# 4                      2                   7.1      380.42
# ...                  ...                   ...         ...
# 4995                  10                   8.3      385.31
# 4996                   4                   4.0         NaN
# 4997                   4                   6.3      358.01
# 4998                   1                   8.4      411.14
# 4999                   2                   6.1      341.72
#
# [5000 rows x 24 columns]

# %%
def calculate_average(row):
    return (row['Attendance (%)'] + row['Midterm_Score'] + row['Final_Score'] + row['Assignments_Avg'] + row['Quizzes_Avg'] + row['Participation_Score'] + row['Projects_Score']) / 7

df['Average_Score'] = df.apply(calculate_average, axis=1)
df['Average_Score']
# Out:
# 0       59.044286
# 1             NaN
# 2       64.308571
# 3       68.828571
# 4       62.085714
#           ...
# 4995          NaN
# 4996          NaN
# 4997    63.650000
# 4998    71.957143
# 4999    60.805714
# Name: Average_Score, Length: 5000, dtype: float64

# %%
#how to categorize students based on their average score using .apply and .map
def categorize_students(row):
    if row['Average_Score'] >= 80:
        return "Excellent"
    elif row['Average_Score'] >= 70:
        return 'Good'
    elif row['Average_Score'] >= 60:
        return 'Average'
    elif row['Average_Score'] >= 50:
        return 'Poor'
    else:
        return 'Failure'
    
df['Category'] = df.apply(categorize_students, axis=1)
df['Category']
df
# Out:
#      Student_ID First_Name Last_Name                       Email  Gender  Age  \
# 0         S1000       Omar  Williams     student0@university.com    Male   22
# 1         S1001      Maria     Brown     student1@university.com  Female   18
# 2         S1002      Ahmed     Jones     student2@university.com  Female   24
# 3         S1003       Omar  Williams     student3@university.com    Male   24
# 4         S1004       John     Smith     student4@university.com    Male   23
# ...         ...        ...       ...                         ...     ...  ...
# 4995      S5995      Ahmed     Jones  student4995@university.com  Female   19
# 4996      S5996       Emma     Brown  student4996@university.com  Female   19
# 4997      S5997       John     Brown  student4997@university.com    Male   24
# 4998      S5998       Sara     Davis  student4998@university.com  Female   23
# 4999      S5999      Maria     Brown  student4999@university.com    Male   21
#
#        Department  Attendance (%)  Midterm_Score  Final_Score  ...  \
# 0     Engineering           52.29          55.03        57.82  ...
# 1     Engineering           97.27          97.23        45.80  ...
# 2        Business           57.19          67.05        93.68  ...
# 3     Mathematics           95.15          47.79        80.63  ...
# 4              CS           54.18          46.59        78.89  ...
# ...           ...             ...            ...          ...  ...
# 4995     Business             NaN          82.15        60.33  ...
# 4996     Business           65.11          86.31        49.80  ...
# 4997           CS           87.54          63.55        64.21  ...
# 4998           CS           92.56          79.79        94.28  ...
# 4999  Engineering           83.92          83.24        53.47  ...
#
#       Study_Hours_per_Week  Extracurricular_Activities  \
# 0                      6.2                          No
# 1                     19.0                          No
# 2                     20.7                          No
# 3                     24.8                         Yes
# 4                     15.4                         Yes
# ...                    ...                         ...
# 4995                  25.5                          No
# 4996                   5.0                          No
# 4997                  24.8                         Yes
# 4998                  16.1                         Yes
# 4999                  29.2                          No
#
#       Internet_Access_at_Home  Parent_Education_Level  Family_Income_Level  \
# 0                         Yes             High School               Medium
# 1                         Yes                    None               Medium
# 2                         Yes                Master's                  Low
# 3                         Yes             High School                 High
# 4                         Yes             High School                 High
# ...                       ...                     ...                  ...
# 4995                      Yes             High School                  Low
# 4996                      Yes                     NaN               Medium
# 4997                       No             High School               Medium
# 4998                      Yes              Bachelor's                  Low
# 4999                      Yes                     PhD                  Low
#
#      Stress_Level (1-10)  Sleep_Hours_per_Night Total Score Average_Score  \
# 0                      5                    4.7      361.02     59.044286
# 1                      4                    9.0         NaN           NaN
# 2                      6                    6.2      392.97     64.308571
# 3                      3                    6.7      386.65     68.828571
# 4                      2                    7.1      380.42     62.085714
# ...                  ...                    ...         ...           ...
# 4995                  10                    8.3      385.31           NaN
# 4996                   4                    4.0         NaN           NaN
# 4997                   4                    6.3      358.01     63.650000
# 4998                   1                    8.4      411.14     71.957143
# 4999                   2                    6.1      341.72     60.805714
#
#      Category
# 0        Poor
# 1     Failure
# 2     Average
# 3     Average
# 4     Average
# ...       ...
# 4995  Failure
# 4996  Failure
# 4997  Average
# 4998     Good
# 4999  Average
#
# [5000 rows x 26 columns]

# %%
def categorize_score(score):
    if score >= 80:
        return "Excellent"
    elif score >= 70:
        return 'Good'
    elif score >= 60:
        return 'Average'
    elif score >= 50:
        return 'Poor'
    else:
        return 'Failure'
df['Category'] = df['Average_Score'].map(categorize_score)
df.head()
# Out:
#   Student_ID First_Name Last_Name                    Email  Gender  Age  \
# 0      S1000       Omar  Williams  student0@university.com    Male   22
# 1      S1001      Maria     Brown  student1@university.com  Female   18
# 2      S1002      Ahmed     Jones  student2@university.com  Female   24
# 3      S1003       Omar  Williams  student3@university.com    Male   24
# 4      S1004       John     Smith  student4@university.com    Male   23
#
#     Department  Attendance (%)  Midterm_Score  Final_Score  ...  \
# 0  Engineering           52.29          55.03        57.82  ...
# 1  Engineering           97.27          97.23        45.80  ...
# 2     Business           57.19          67.05        93.68  ...
# 3  Mathematics           95.15          47.79        80.63  ...
# 4           CS           54.18          46.59        78.89  ...
#
#    Study_Hours_per_Week  Extracurricular_Activities  Internet_Access_at_Home  \
# 0                   6.2                          No                      Yes
# 1                  19.0                          No                      Yes
# 2                  20.7                          No                      Yes
# 3                  24.8                         Yes                      Yes
# 4                  15.4                         Yes                      Yes
#
#    Parent_Education_Level  Family_Income_Level Stress_Level (1-10)  \
# 0             High School               Medium                   5
# 1                    None               Medium                   4
# 2                Master's                  Low                   6
# 3             High School                 High                   3
# 4             High School                 High                   2
#
#    Sleep_Hours_per_Night Total Score Average_Score Category
# 0                    4.7      361.02     59.044286     Poor
# 1                    9.0         NaN           NaN  Failure
# 2                    6.2      392.97     64.308571  Average
# 3                    6.7      386.65     68.828571  Average
# 4                    7.1      380.42     62.085714  Average
#
# [5 rows x 26 columns]

# %%
excellent_students = df[df['Category'] == 'Failure']
excellent_students
# Out:
#      Student_ID First_Name Last_Name                       Email  Gender  Age  \
# 1         S1001      Maria     Brown     student1@university.com  Female   18
# 5         S1005       Liam     Brown     student5@university.com  Female   21
# 20        S1020       Emma     Davis    student20@university.com  Female   18
# 32        S1032      Maria     Smith    student32@university.com    Male   21
# 46        S1046       Liam     Smith    student46@university.com  Female   24
# ...         ...        ...       ...                         ...     ...  ...
# 4991      S5991       John  Williams  student4991@university.com    Male   20
# 4992      S5992       Sara   Johnson  student4992@university.com  Female   18
# 4994      S5994       John   Johnson  student4994@university.com    Male   19
# 4995      S5995      Ahmed     Jones  student4995@university.com  Female   19
# 4996      S5996       Emma     Brown  student4996@university.com  Female   19
#
#        Department  Attendance (%)  Midterm_Score  Final_Score  ...  \
# 1     Engineering           97.27          97.23        45.80  ...
# 5     Engineering             NaN          78.85        43.53  ...
# 20             CS           77.13          69.94        46.70  ...
# 32             CS             NaN          61.59        98.60  ...
# 46             CS             NaN          69.91        44.14  ...
# ...           ...             ...            ...          ...  ...
# 4991  Engineering           55.54          59.68        63.09  ...
# 4992           CS             NaN          61.44        64.59  ...
# 4994  Mathematics             NaN          69.92        55.48  ...
# 4995     Business             NaN          82.15        60.33  ...
# 4996     Business           65.11          86.31        49.80  ...
#
#       Study_Hours_per_Week  Extracurricular_Activities  \
# 1                     19.0                          No
# 5                      8.5                         Yes
# 20                    16.9                          No
# 32                    28.9                          No
# 46                    13.5                          No
# ...                    ...                         ...
# 4991                  18.8                         Yes
# 4992                  23.3                         Yes
# 4994                  25.5                          No
# 4995                  25.5                          No
# 4996                   5.0                          No
#
#       Internet_Access_at_Home  Parent_Education_Level  Family_Income_Level  \
# 1                         Yes                    None               Medium
# 5                         Yes                     PhD                 High
# 20                        Yes             High School               Medium
# 32                        Yes                    None               Medium
# 46                        Yes                Master's                  Low
# ...                       ...                     ...                  ...
# 4991                      Yes                     NaN                  Low
# 4992                       No             High School               Medium
# 4994                      Yes             High School                  Low
# 4995                      Yes             High School                  Low
# 4996                      Yes                     NaN               Medium
#
#      Stress_Level (1-10)  Sleep_Hours_per_Night Total Score Average_Score  \
# 1                      4                    9.0         NaN           NaN
# 5                      1                    5.0      319.65           NaN
# 20                     2                    8.1         NaN           NaN
# 32                     9                    4.4      378.20           NaN
# 46                     5                    8.6      377.65           NaN
# ...                  ...                    ...         ...           ...
# 4991                   5                    6.8         NaN           NaN
# 4992                   1                    6.2         NaN           NaN
# 4994                   2                    4.1      327.41           NaN
# 4995                  10                    8.3      385.31           NaN
# 4996                   4                    4.0         NaN           NaN
#
#      Category
# 1     Failure
# 5     Failure
# 20    Failure
# 32    Failure
# 46    Failure
# ...       ...
# 4991  Failure
# 4992  Failure
# 4994  Failure
# 4995  Failure
# 4996  Failure
#
# [1002 rows x 26 columns]

# %%
above_ninety = df[df['Average_Score'] >= 90]
above_ninety
# Out:
# Empty DataFrame
# Columns: [Student_ID, First_Name, Last_Name, Email, Gender, Age, Department, Attendance (%), Midterm_Score, Final_Score, Assignments_Avg, Quizzes_Avg, Participation_Score, Projects_Score, Total_Score, Grade, Study_Hours_per_Week, Extracurricular_Activities, Internet_Access_at_Home, Parent_Education_Level, Family_Income_Level, Stress_Level (1-10), Sleep_Hours_per_Night, Total Score, Average_Score, Category]
# Index: []
#
# [0 rows x 26 columns]

# %%
max_of_three_numbers = lambda x,y,z: max(x,y,z)
result = max_of_three_numbers(100,210,305)
result
# Out:
# 305

# %%
concatenate = lambda x,y: x + y
result = concatenate('data science','is fun')
result
# Out:
# 'data scienceis fun'

# %%
df
# Out:
#      Student_ID First_Name Last_Name                       Email  Gender  Age  \
# 0         S1000       Omar  Williams     student0@university.com    Male   22
# 1         S1001      Maria     Brown     student1@university.com  Female   18
# 2         S1002      Ahmed     Jones     student2@university.com  Female   24
# 3         S1003       Omar  Williams     student3@university.com    Male   24
# 4         S1004       John     Smith     student4@university.com    Male   23
# ...         ...        ...       ...                         ...     ...  ...
# 4995      S5995      Ahmed     Jones  student4995@university.com  Female   19
# 4996      S5996       Emma     Brown  student4996@university.com  Female   19
# 4997      S5997       John     Brown  student4997@university.com    Male   24
# 4998      S5998       Sara     Davis  student4998@university.com  Female   23
# 4999      S5999      Maria     Brown  student4999@university.com    Male   21
#
#        Department  Attendance (%)  Midterm_Score  Final_Score  ...  \
# 0     Engineering           52.29          55.03        57.82  ...
# 1     Engineering           97.27          97.23        45.80  ...
# 2        Business           57.19          67.05        93.68  ...
# 3     Mathematics           95.15          47.79        80.63  ...
# 4              CS           54.18          46.59        78.89  ...
# ...           ...             ...            ...          ...  ...
# 4995     Business             NaN          82.15        60.33  ...
# 4996     Business           65.11          86.31        49.80  ...
# 4997           CS           87.54          63.55        64.21  ...
# 4998           CS           92.56          79.79        94.28  ...
# 4999  Engineering           83.92          83.24        53.47  ...
#
#       Study_Hours_per_Week  Extracurricular_Activities  \
# 0                      6.2                          No
# 1                     19.0                          No
# 2                     20.7                          No
# 3                     24.8                         Yes
# 4                     15.4                         Yes
# ...                    ...                         ...
# 4995                  25.5                          No
# 4996                   5.0                          No
# 4997                  24.8                         Yes
# 4998                  16.1                         Yes
# 4999                  29.2                          No
#
#       Internet_Access_at_Home  Parent_Education_Level  Family_Income_Level  \
# 0                         Yes             High School               Medium
# 1                         Yes                    None               Medium
# 2                         Yes                Master's                  Low
# 3                         Yes             High School                 High
# 4                         Yes             High School                 High
# ...                       ...                     ...                  ...
# 4995                      Yes             High School                  Low
# 4996                      Yes                     NaN               Medium
# 4997                       No             High School               Medium
# 4998                      Yes              Bachelor's                  Low
# 4999                      Yes                     PhD                  Low
#
#      Stress_Level (1-10)  Sleep_Hours_per_Night Total Score Average_Score  \
# 0                      5                    4.7      361.02     59.044286
# 1                      4                    9.0         NaN           NaN
# 2                      6                    6.2      392.97     64.308571
# 3                      3                    6.7      386.65     68.828571
# 4                      2                    7.1      380.42     62.085714
# ...                  ...                    ...         ...           ...
# 4995                  10                    8.3      385.31           NaN
# 4996                   4                    4.0         NaN           NaN
# 4997                   4                    6.3      358.01     63.650000
# 4998                   1                    8.4      411.14     71.957143
# 4999                   2                    6.1      341.72     60.805714
#
#                Category
# 0     Needs Improvement
# 1     Needs Improvement
# 2               Average
# 3               Average
# 4               Average
# ...                 ...
# 4995  Needs Improvement
# 4996  Needs Improvement
# 4997            Average
# 4998            Average
# 4999            Average
#
# [5000 rows x 26 columns]
